# %% [markdown]
# ### Exercise 4
#
# Draw a stack diagram for the following program. What does the program print?
#
# You can do this on paper, using [Python Tutor](http://pythontutor.com/), or with [Lumpy](http://www.greenteapress.com/thinkpython/swampy/) as used in [Allen's solution](http://thinkpython.com/code/stack_diagram.py).

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %% [markdown]
# I used Python Tutor and ended with 5 global frames (b, a, c, x, y) and 3 objects (b(z), a(x,y), c(x,y,z)).

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
# i did the thing but am unsure how to show that in jupyter.

def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# I do not know how to put an image in jupyter. So I will describe it here.
# First it runs c then calls b(z) then calls a(x,y). The result of a(x,y) is returned into b(z). 
# Then, b(z) prints '9 90' which is z and prod. Then it returns 90 into c(x,y,z)
# Next, c(x,y,z) returns 1800 and it is printed.
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print(z, prod)
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print(c(x, y+3, x+y))
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#I visualized it using python tutor
#frame 1 = global frame has a function b that takes in z, and a function a that takes in x and y, and a function c that takes in x, y, and z
#global frame assigns x = 1
#global frame assigns y = 2
#fram2 = frame c assigns x = 1, y = 5, z = 3, and total = 9
#fram3 = frame b assigns z = 9
#fram4 = frame a assigns x = 9, y = 9
#frame a reassigns x = 10, returns value 90, disappears
#frame b returns prod value 90, returns value 90, disappears
#frame c returns square 8100, returns value 8100, disappears

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#http://pythontutor.com/visualize.html#code=def+b(z%29%3A%0A++++prod+%3D+a(z,+z%29%0A++++print+z,+prod%0A++++return+prod%0Adef+a(x,+y%29%3A%0A++++x+%3D+x+%2B+1%0A++++return+x+*+y%0A%0Adef+c(x,+y,+z%29%3A%0A++++total+%3D+x+%2B+y+%2B+z%0A++++square+%3D+b(total%29**2%0A++++return+square%0A%0Ax+%3D+1%0Ay+%3D+x+%2B+1%0Aprint+c(x,+y%2B3,+x%2By%29&mode=display&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&py=2&rawInputLstJSON=%5B%5D&curInstr=20

print 'It prints 9 90 and then 8100'
# Out:
# 9 90
# 8100
# It prints 9 90 and then 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
from swampy.Lumpy import Lumpy

def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    #lumpy.object_diagram()
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

#lumpy = Lumpy()
#lumpy.make_reference()

x = 1
y = x + 1
print c(x, y+3, x+y)

#Used Python Tutor to  helpvisualize it
#c --> x = 1, y = 5, z = 3, total = 9 --> b(9)
#b --> z = 9 --> a(9,9)
#a --> x = 9, y = 9 -->  returns prod = 90 for b(9)
#b returns 9 90 for z, prod
#c returns 90**2
#9 90 and 8100 are returned
# Out:
# 9 90
# 8100

# %% [markdown]
# This function is printing the square of ((x+y+z)+1) * (x+y+z)
# It's cool how it's calling the different functions within each other

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
'''from swampy.Lumpy import Lumpy
lumpy = Lumpy()
lumpy.make_reference()'''

def b(z):
    prod = a(z, z)
    #print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

'''lumpy.object_diagram()'''
# Out:
# 8100
# 'lumpy.object_diagram()'

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#http://pythontutor.com/visualize.html#mode=display
#the program prints 9 and 90 (z and prod from within b()), 
#and 8100 (the output of c())

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
from swampy.Lumpy import Lumpy

def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

lumpy = Lumpy()
lumpy.make_reference()

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print(z, prod)
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print(c(x, y+3, x+y)) #should be 90^2
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#The program prints 9 90
#                   8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#This program prints the total of 1, 1+1+3, and 1+1+1 (which is 9) then
#9*(9 + 1) (the output of function a(x,y)), then prints 8100 (90^2)
#(the output of function c(x,y,z))

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)  # a(9, 9)
    print z, prod  # 9, 90
    return prod  # 90

def a(x, y):
    x = x + 1  # (10)
    return x * y  # 10 * 9 = 90

def c(x, y, z):
    total = x + y + z  # 1 + 5 + 3 = 9
    square = b(total)**2 # b(9)**2 = 90**2 = 8100
    return square

x = 1  # 1
y = x + 1  # 2
print c(x, y+3, x+y)  # c(1, 5, 3) = 8100

# yup. sounds good.

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#we define x = 1 and y = x+1 = 2 globally.
#next, within c we definte total = x + y+3 + x+y = 9.
#we make a variable within c called square and call b on 9, then square the result.
#calling b on 9 defines a variable, prod, in b, which equals a(9, 9).
#calling a on (9,9) returns 9 * 9+1 = 90.
#b now prints 9 90 and returns b(total) = 90, which is then squared to give square a value of 8100.
#finally, c returns square.
#all functions collapse and variables defined within each function are lost after the return.

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# Gonna print: 9, 90, 8100
# Out:
# 9 90
# 8100

# %% [raw]
# def b(z):
#     prod = a(z, z)
#     print z, prod
#     return prod
#
# def a(x, y):
#     x = x + 1
#     return x * y
#
# def c(x, y, z):
#     total = x + y + z
#     square = b(total)**2
#     return square
#
# x = 1
# y = x + 1
# print c(x, y+3, x+y)

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

#output
#9 90
#8100
# Out:
# 9 90
# 8100

# %%
from swampy.Lumpy import Lumpy

def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
#     lumpy.object_diagram()
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

lumpy = Lumpy()
lumpy.make_reference()

x = 1
y = x + 1
print c(x, y+3, x+y)

# I first went through this with Python Tutor, then tried Lumpy. As far
# as I can tell, it produced an object diagram of the entire ipython
# framework, and possibly more. Interesting, but a bit unmanageable.
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)
# Out:
# 9 90
# 8100

# %%
def b(z):
    prod = a(z, z)
    print z, prod
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print c(x, y+3, x+y)

# %% [markdown]
# ### Exercise 6
#
# A palindrome is a word that is spelled the same backward and forward, like “noon” and “redivider”. Recursively, a word is a palindrome if the first and last letters are the same and the middle is a palindrome.
#
# You can use the `first`, `last`, and `middle` helper functions defined in Think Python, or do the string slices inside your function directly. Be sure to think about your base cases.
#
# Write a function called `is_palindrome` that takes a string argument and returns `True` if it is a palindrome and `False` otherwise. Remember that you can use the built-in function `len` to check the length of a string.
#
# Write some unit tests for your function (optionally using doctest) to show that it works as intended.

# %%
def first(word):
    return word[0]
def last(word):
    return word[-1]
def middle(word):
    return word[1:-1]

def is_palindrome(word):
    if first(word)==last(word):
        if len(word)<=2:
            return True
        else:
            return is_palindrome (middle(word)) 
    else:
        return False
is_palindrome('redivider')
# Out:
# True

# %%
def is_palindrome(x):
    if len(x) >= 3: 
        if x[0] == x[-1]:
            return is_palindrome(x[1:-1])
        else:
            return False
    elif x[0] == x[-1]:
        return True
    else:
        return False
    
    

print is_palindrome('redivider')    
print is_palindrome('KAIAK')
print is_palindrome('2333')
is_palindrome('233')
# Out:
# True
# True

# %%
def is_palindrome (x):
    """
>>> is_palindrome("cart")
    False
>>> is_palindrome("bobob")
    True
>>> is_palindrome("kayak")
    True
    """
    for i in range(len(x)):
        if x == x[::-1]:
            return True
    else:
        return False


if __name__ == "__main__":
	import doctest
doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 3, in __main__.is_palindrome
# Failed example:
#     is_palindrome("cart")
# Expected:
#         False
# Got:
#     False
# **********************************************************************
# File "__main__", line 5, in __main__.is_palindrome
# Failed example:
#     is_palindrome("bobob")
# Expected:
#         True
# Got:
#     True
# **********************************************************************
# File "__main__", line 7, in __main__.is_palindrome
# Failed example:
#     is_palindrome("kayak")
# Expected:
#         True
# Got:
#     True
# **********************************************************************
# 1 items had failures:
#    3 of   3 in __main__.is_palindrome
# ***Test Failed*** 3 failures.
# TestResults(failed=3, attempted=3)

# %%
def is_pallindrome(string):
    string = string.lower()
    if len(string)>1:
        if string[0] == string[len(string)-1]:
            string = string[1:len(string)-1]
            return True
        if string[0] != string[len(string)-1]:
            return False
    return is_pallindrome(string)
            
    
#     print first, last, middle
    
print is_pallindrome("pallindrome")
print is_pallindrome("Noon")
print is_pallindrome("redivider")
print is_pallindrome("hello")
# Out:
# False
# True
# True
# False

# %%
string = ''

# %%
def is_palindrome(s):
    """
    >>> is_palindrome("Go hand a salami Im a lasagna hog") # even palindrome
    True
    >>> is_palindrome("Ah Satan sees Natasha")
    True
    >>> is_palindrome("No melons no lemon") # odd palindrome
    True
    >>> is_palindrome("Now I see bees I lost") # not a palindrome
    False
    """
    
    s = s.strip().lower()
    if len(s) <= 1:
        return True
    if s[0] == s[len(s)-1]:
        return is_palindrome(s[1::len(s)-1])
    else:
        return False


import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %%
import string

def is_palindrome(word):
    """this function tells you if the string input is a palindrome. doctests are from xkcd 1632.
    >>> is_palindrome('a man a plan a gods nam tables nitrate tar tinsel batmans dog anal panama')
    True
    >>> is_palindrome('i hope that somewhere in the world panamax is the last option on a size drop down menu on a sex toy site')
    False
    """
    one_word = word.replace(' ','')
    if len(one_word) == 0:
        return True
    if len(one_word) == 1:
        return True
    elif one_word[0] == one_word[-1]:
        return is_palindrome(one_word[1:-1])
    else:
        return False

import doctest
doctest.run_docstring_examples(is_palindrome, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     is_palindrome('a man a plan a gods nam tables nitrate tar tinsel batmans dog anal panama')
# Expecting:
#     True
# ok
# Trying:
#     is_palindrome('i hope that somewhere in the world panamax is the last option on a size drop down menu on a sex toy site')
# Expecting:
#     False
# ok

# %%
def isPalindrome(words):
    """
    Takes a string and returns True if that string is a palindrome.
    
    >>> isPalindrome("kayak")
    True
    >>> isPalindrome("live on time, emit no evil")
    True
    >>> isPalindrome("hello")
    False
    """
    punctuation = [' ','.',',','"',"'",'!','?','-','—','+','=','(',')']
    for char in punctuation:
          words = words.replace(str(char), '')
    words = words.lower()
    return checkEnds(words)
    
    
def checkEnds(x):
    """
    >>> checkEnds("kayak")
    True
    >>> checkEnds("hello")
    False
    >>> checkEnds("a")
    True
    """
    if len(x) > 1:
        if x[0] == x[-1]:
            if len(x) > 2:
                if checkEnds(x[1:-1]):
                    return True
            elif len(x) == 2:
                return True
        else:
            return False
    elif len(x) == 1:
        return True
    else: # len(x) == 0
        return False

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=12)

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]
     
def is_palindrome(word):
    flag = True
    if len(word) == 1:
        return True
    if len(word) < 3: #when len == 2
        return first(word) == last(word)
    return (first(word) == last(word) and is_palindrome(middle(word)))

print is_palindrome('noon')
print is_palindrome('racecar')
print is_palindrome('doom')
# Out:
# True
# True
# False

# %%
def first(word):
    return word[0]
def last(word):
    return word[-1]
def middle(word):
    return word[1:-1]
def is_palindrome(WoRd):
    """ Returns True/False for if input is a palindrome.
    >>> is_palindrome('word')
    False
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('Racecar')
    True
    >>> is_palindrome('redivider')
    True
    >>> is_palindrome('l')
    True
    """
    word = WoRd.lower()
    if len(word) < 3:
        if first(word) == last(word):
            return True
        else:
            return False
    if len(word) >= 3:
        if first(word) == last(word):
            return is_palindrome(middle(word))
        else:
            return False
    
if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def palindrome(word):
    """
    Recursively looks through a string and determines if it is a palindrome.
    
    >>> palindrome('racecar')
    True
    
    >>> palindrome('abba')
    True
    
    >>> palindrome('palindrome')
    False
    
    """
    if len(word) < 2:
        return True
    elif word[0] == word[-1]:
        return palindrome(word[1:-1])
    return False
        
import doctest
doctest.run_docstring_examples(palindrome, globals())

# %%
'''

>>> is_palindrome("redivider")
True

>>> is_palindrome("bob")
True

>>> is_palindrome("ttta")
False

>>> is_palindrome("aaaaaaa")
True

'''

def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(word):
    mid = middle(word)
    if first(word) == last(word):    
        if mid[:] == mid[::-1]:
            return True
    return False

import doctest
doctest.testmod()
doctest.run_docstring_examples(is_palindrome, globals())

# %%
def is_palindrome(word):
    word_list = list(word)
    length = len(word_list)
    if length <= 2:
        return False
    elif length > 2:
        for letters in word_list:
            if word_list[0] == word_list[-1]:
                del(word_list[0])
                del(word_list[-1])
    if len(word_list)== 0:
        return True
    else:
        return False
    
print(is_palindrome('noon'))
# Out:
# True

# %%
def is_palindrome(word):
    forward = word
    backward = word[::-1]
    if forward == backward:
        return True
    return False

is_palindrome("racecar")
#is_palindrome("papyrus")
# Out:
# True

# %%
def first(word):
    return word[0]
def last(word):
    return word[-1]
def middle(word):
    return word[1: -1]

def is_palindrome(word):# function is caSe SenSitiVe
    if len(word) > 1:
        if first(word) == last(word):
            return is_palindrome(middle(word))
        else:
            return False
    else:
        return True
        
is_palindrome('racecar')
# Out:
# True

# %%
def is_palindrome(s):
    if len(s) < 1:
        return True
    elif s[0] == s[len(s)-1]:
        return is_palindrome(s[1:len(s)-1])
    else:
        return False
print(is_palindrome('rotor'))
print(is_palindrome('a'))
print(is_palindrome('hello'))
# Out:
# True
# True
# False

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(pali):
#    print first(pali)
#    print last(pali)

    if len(pali) == 2:
        if pali[0] == pali[1]:
            return True
        else:
            return False
    
    if len(pali) < 2:
#        print "got to the end"
        return True
    
    if first(pali) == last(pali):
#        print "first(pali) == last(pali)"
        return is_palindrome(middle(pali))
      
    return False

is_palindrome("kayak")
# Out:
# True

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def palindrome(a):
    """
    Returns Boolean assignment True or False to determine if word is palindrome.
    
    >>> palindrome('DogGOD')
    True
    >>> palindrome('RACE car')
    True
    >>> palindrome('allen')
    False
    >>> palindrome('PAul ruvOLo')
    False
    >>> palindrome('stanley YELnats')
    True
    """
    a = a.lower() #converts all characters in a to lowercase
    a = a.rstrip() #strips all spaces from a
    if len(a) <= 1:
        return True
    elif first(a) != last(a):
        return False
    return palindrome(middle(a))

if __name__ == "__main__":
    import doctest
    doctest.testmod()
#what do you know, it works
#fun with palindromes
palindrome('Borrow or Rob') #a moral dilemma
palindrome('Murder for a jar of red rum') #creepiest childhood game
palindrome('Yo Banana Boy') #it's Gabe
palindrome('satan oscillate my metallic sonatas') #that's unfortunate
palindrome('SolO GIGOLOS') #I am having altogether to much fun with this
palindrome('dammit Im mad')#lol not really but I bet whoever's reading this is
# Out:
# True

# %%
import doctest

def is_palindrome2 (x): 
    
    """ 
    This function is meant to show True if the string is a palindrome and False if it is not.
    >>> is_palindrome ("MADAMIMADAM")
    True 
    >>> is_palindrome("MADAMI'MADAM")
    False 
    >>> is_palindrome("horse")
    False
    >>> is_palindrome("")
    True
    >>> is_palindrome(".")
    True
    """
    a = list(x)
    
    last_string = '' 
    for i in x: 
        last_string+=(a[-1]) 
        del a[-1]
    last_string
    
    if x == last_string:
        return True 
    else:
        return False
    
is_palindrome2 (".")

doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 6, in __main__.is_palindrome
# Failed example:
#     is_palindrome ("MADAMIMADAM")
# Expected:
#     True
# Got:
#     True
# **********************************************************************
# File "__main__", line 8, in __main__.is_palindrome
# Failed example:
#     is_palindrome("MADAMI'MADAM")
# Expected:
#     False
# Got:
#     False
# **********************************************************************
# File "__main__", line 6, in __main__.is_palindrome2
# Failed example:
#     is_palindrome ("MADAMIMADAM")
# Expected:
#     True
# Got:
#     True
# **********************************************************************
# File "__main__", line 8, in __main__.is_palindrome2
# Failed example:
#     is_palindrome("MADAMI'MADAM")
# Expected:
#     False
# Got:
#     False
# **********************************************************************
# 2 items had failures:
# ...

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]
"""
>>> is_palindrome('')
True
>>> is_palindrome('a')
True
>>> is_palindrome('redivider')
True
>>> is_palindrome('redeemer')
False
"""


def is_palindrome(string):
    if len(string)<=1:
        return True
    elif first(string)==last(string) and is_palindrome(middle(string))==True:
        return True
    else:
        return False
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %% [markdown]
# ### Challenge (optional)
#
# Use the word list from [Chapter 9.1](http://www.greenteapress.com/thinkpython/html/thinkpython010.html) Exercise 1 to find all of the palindromes.

# %%
flag = False
def is_palindrome(word):
    if len(word) < 2:
        return True
    elif (first(word) == last(word)):
        mid = middle(word)
        is_palindrome(mid)
    else:
        return False

def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

print is_palindrome('racecar')
# Out:
# None

# %%
def first(word):
    return word[0]

def middle(word):
    return word[1:-1]

def last(word):
    return word[-1]


def is_palindrome(word):
    if len(word) <= 1:
        return True
    else: 
        f = first(word)
        l = last(word)
        if f == l:
            return is_palindrome(middle(word)) #calls itself with updated word
        elif f!=l:
            return False
is_palindrome('arozaupalanalapuazora')
# Out:
# True

# %% [markdown]
# Recursive functions must have one or more base cases that end the execution of the loop.

# %%
def is_palindrome_nr(word): #non-recursive version... 
    if word == word[::-1]:
        return True
    return False

def is_palindrome(word):
    
    if len(word) in [1,0]:
        return True
    
    elif word[0] == word[len(word)-1]:
        return is_palindrome(word[1:len(word)-1])
    
    else:
        return False

is_palindrome('racecar') #True
#is_palindrome('1234321') #True
#is_palindrome('tan nat') #True
#is_palindrome('Racecar') #False (do we need to worry about case?)
#is_palindrome('palindrome') #False
# Out:
# True

# %%
def is_palindrome(s):
    if len(s) <= 1 :
        return True
    elif s[0] == s[len(s)-1]:
        s1 = s[1:len(s)-1]
        return is_palindrome(s1)
    
    return False

is_palindrome('hannah')
# Out:
# True

# %%
def is_palindrome(word):
    """ Uses recursion to check if a word is a palindrome
    >>> is_palindrome('noon')
    True
    >>> is_palindrome('never')
    False
    """
    word = word.lower()
    if len(word) > 1:
        if word[0] == word[-1] and is_palindrome(middle(word)):
            return True
        else:
            return False
    else:
        return True
        
def middle(word):
    return word[1:-1]

import doctest
doctest.testmod()

print is_palindrome('why this')
print is_palindrome('yay')
# Out:
# False
# True

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(word):
    if len(word) == 0:
        return True
    elif first(word) == last(word):
        return is_palindrome(middle(word))
    else:
        return False
    
#is_palindrome('banana')
#is_palindrome('baab')
    
"""
>>> is_palindrome('b')
True
>>> is_palindrome('ba')
False
"""

if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def first(word): #first letter of word
    return word[0]

def middle(word): #middle of word
    return word[1:-1]

def last(word):
    return word[-1] #last letter of word

def is_palindrome(word):
    """ Determines if 'word' is a palindrome

        word: a word represented as a string
        returns: True if 'word' is a palindrome and False if not
    >>> is_palindrome("hello")
    False
    >>> is_palindrome("racecar")
    True
    >>> is_palindrome("wow")
    True
    >>> is_palindrome("I")
    True
    """
    if len(word) <= 1:
        return True
    if first(word) != last(word):
        return False
    return is_palindrome(middle(word))

if __name__ == "__main__": #doctest works when I run it through sublime/terminal...yay!
    import doctest
    doctest.testmod()

print is_palindrome('racecar')
print is_palindrome('hello')
# Out:
# True
# False

# %%
def is_palindrome(word):
    """
    Checks whether a string is a palindrome using recursion.
    
    >>> is_palindrome('neveroddoreven')
    True
    >>> is_palindrome('never odd')
    False
    >>> is_palindrome('mom')
    True
    >>> is_palindrome('moabcom')
    False
    """
    
    word = word.lower()
    if len(word) > 1:
        return word[0] == word[-1] and is_palindrome(center(word))
    else:
        return True
def center(word):
    return word[1:-1]

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %%
def is_palindrome(word):
    print word
#    word.replace(' ', '')  #was a nice idea, but isn't working.
    if len(word)==0 or len(word)==1:
        return True
    elif word[0]== word[len(word)-1]:
        word= word[1:len(word)-1]
        recurse= is_palindrome(word)
        return recurse
    else :
        return False
    
is_palindrome('tacocat')
# Out:
# tacocat
# acoca
# coc
# o
# True

# %%
'''returns the first letter of a word

>>> first('ariana')
'a'

'''
def first(word):
    return word[0]
'''returns the last letter of a word

>>> last('ariana')
'a'

'''
def last(word):
    return word[-1]
'''returns the word with the first and last letters removed

>>> middle('ariana')
'rian'

'''
def middle(word):
    return word[1:-1]
'''checks recursively if a word is a palindrome

>>> is_palindrome('redivider')
True
>>> is_palindrome('banana')
False
>>> is_palindrome('')
True


'''
def is_palindrome(word):
    if len(word) == 0:
        return True
    else:
        if last(word) == first(word):
            #slices the forst and last letters off the word and checks if that's a palindrome
            return is_palindrome(middle(word)) 
        else: 
            return False
is_palindrome('apple')

print is_palindrome('redivider')
print is_palindrome('banana')
import doctest
doctest.testmod(verbose = True)
# Out:
# True
# False
# Trying:
#     is_palindrome('redivider')
# Expecting:
#     True
# ok
# Trying:
#     is_palindrome('banana')
# Expecting:
#     False
# ok
# Trying:
#     is_palindrome(' ')
# Expecting:
#     True
# ok
# 7 items had no tests:
#     __main__.a
#     __main__.b
#     __main__.c
#     __main__.first
#     __main__.is_palindrome
#     __main__.last
#     __main__.middle
# 1 items passed all tests:
#    3 tests in __main__
# 3 tests in 8 items.
# 3 passed and 0 failed.
# Test passed.
# TestResults(failed=0, attempted=3)

# %%
def is_palindrome(astring):
    if len(astring) > 2:
        if astring[::-1] == astring:
            return True
        else:
            return False
    else:
        return "A palindrome needs to be at least 3 letters long. Try again."

print is_palindrome("aa")
print is_palindrome("redivider")
print is_palindrome("octopus")

# %%
def is_palindrome(word):
    wordlist = list(word)
    if len(wordlist) == 0 or len(wordlist) == 1 :
        return True
    else:
        if wordlist[0] == wordlist[-1]:        
            del wordlist[0]
            del wordlist[-1]
            #print wordlist
            is_palindrome(wordlist)
        else: 
            print False
        
is_palindrome('noon')

# %%
def is_palindrome(word):
    """
    takes string input and returns True if it is a palindrome, returns 
    False otherwise
    
    >>> is_palindrome("noon")
    True
    >>> is_palindrome("nope")
    False
    >>> is_palindrome("never mind")
    False
    """
    if word == word[::-1]:
        return True
    else:
        return False
    
import doctest
doctest.run_docstring_examples(is_palindrome,globals())

# %%
i = 0
def is_palindrome(word):
    for i in range(len(word)-1):
        a = word[i]
        b = word[len(word)-1]
        if len(word)<=1:
            break
        if len(word)==2:
                if word[0] == word[1]:
                    return True
                else:
                    return False
        if a == b:
            word = word[i+1:len(word)-2]
            if len(word)<=1:
                break
            a = word[i]
            b = word[len(word)-1]
            if len(word)<=1:
                break
            if len(word)==2:
                if word[0] == word[1]:
                    return True
                else:
                    return False  
                
        else:
            return False
    return True

print is_palindrome('ratstar')
print is_palindrome('iwofhouwbrovdb')
# Out:
# False

# %%
def first(word):
    return word[0]
def last(word):
    return word[-1]
def middle(word):
    return word[1:-1]
def is_palindrome(word):
    if first(word) != last(word):
        return "Not a palindrome"
    elif len(word)<3:
        return "Is a palindrome!"
    else:
        return is_palindrome(middle(word))
    print 'wat'
print is_palindrome("amanaplanagodsnamtablesnitratetartinselbatmansdoganalpanama")
print is_palindrome('ugrugur')
# Out:
# Is a palindrome!
# Not a palindrome

# %%
import doctest

def is_palindrome(word):
    '''Checks to see if a word is a palindrome
    >>> is_palindrome('test')
    False
    >>> is_palindrome('noon')
    True
    >>> is_palindrome('neven')
    True
    >>> is_palindrome(12)
    is_palindrome is only defined for strings
    '''
    
    if not isinstance(word,str):
        print 'is_palindrome is only defined for strings'
        return None
    elif len(word) == 0:
        return True
    elif first(word) != last(word):
        return False
    return is_palindrome(middle(word))
    
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %%
def is_palindrome(string):
    for i in range(0, len(string)):
        if string[i] == string[len(string)-1-i]:
            continue
        else:
            return False
    return True
print is_palindrome('amanaplanacanalpanama')
print is_palindrome('apple')
print is_palindrome('appa')
print is_palindrome('racecar')
# Out:
# True
# False
# True
# True

# %%
def palindrome(string):
    return word.replace(' ', '') == word.replace(' ', '')[::-1]

# ok, recursively if you insist:
def is_palindrome(string):
    string = string.replace(' ', '')
    if len(string) < 2:
        return True
    if string[0] != string[-1]:
        return False
    return is_palindrome(string[1:-1])

is_palindrome('rats live on no evil star')
# Out:
# True

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]


def is_palindrome(s):
    '''
    Input string, outpur true/false
    
    >>>is_palindrome(racecar)
    true
    >>>is_palindrome(notpalindrome)
    false
    '''
    word_length = len(s)/2 
    for c in range(word_length):
        if first(s) == last(s):
            s = middle(s)
        else:
            return False
    return True

print is_palindrome('words')
print is_palindrome('car')
print is_palindrome('racecar')
# Out:
# False
# False
# True

# %%
"""
>>>is_palindrome('ABCBA')
True
"""
def is_palindrome(val):
    if(val[-1] != val[0]):
        return False
    elif(len(val) <= 3):
        return True
    else:
        return is_palindrome(val[1:-1])
        
# import doctest
# doctest.run_docstring_examples(is_palindrome, globals(),verbose=True)

print(is_palindrome('BCBA'))
# Out:
# False

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(word):
    '''
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('formula')
    False
    '''
    for i in range(len(word)/2):
        if first(word) == last(word):
            word = middle(word)
            is_palindrome(word)
        else:
            return False
    return True

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=7)

# %%
def is_palindrome(word):
    if(len(word) <= 1):
        return True
    return((word[0] == word[len(word)-1]) and is_palindrome(word[1:len(word) - 1]))

print(is_palindrome('noon'))
print(is_palindrome('redivider'))
print(is_palindrome('noan'))
print(is_palindrome('redivader'))
# Out:
# True
# True
# False
# False

# %%
def is_palindrome(shtring1, shtring2):
    """ A not to great palindrome checker. 
    >>>print is_palindrome("asdfg","gfdsa")
    True
    
    >>>print is_palindrome("asdfgh", "hgfdsa")
    True
    
    >>>print is_palindrome("asdfg", "asdfg")
    False
    
    >>>print is_palindrome("bbb","b")
    False
    """
    if (len(shtring1) != len(shtring2)):
        return False
    if (len(shtring1) == 1) and (shtring1.lower() == shtring2.lower()):
        return True
    if (len(shtring1) == 2) and (shtring1[::-1].lower() == shtring2.lower()):
        return True
    if ((shtring1[:1] != shtring2[-1:]) or (shtring1[-1:] != shtring2[:1])):
        return False
    return is_palindrome(shtring1[1:-1], shtring2[1:-1])

#ooooooooooor

def is_palindrome2(shtring1, shtring2):
    
    
print is_palindrome("asdfg","gfdsa")
print is_palindrome("asdfgh", "hgfdsa")
print is_palindrome("asdfg", "asdfg")
print is_palindrome("bbb","b")
# Out:
# True
# True
# False
# False

# %%
def is_palindrome(s):
    if len(s)==1:
        return True
    elif s[0]==s[-1]:
        if len(s)==2:
            return True
        else:
            return is_palindrome(s[1:-1])
    else:
        return False 

print is_palindrome('rtcgcrtr')
# Out:
# False

# %%
def is_palindrome(word):
    """ Function determines if word is palidrome and returns True if it is and False if it is not
    
    >>> is_palindrome('racecar')
    True
    
    >>> is_palindrome('Racecar')
    True
    
    >>> is_palindrome('banana')
    False

    """
    word = word.lower()
    return word == word[::-1]

is_palindrome('Wow')


if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def is_palindrome(word):
    """ takes a word. Returns True if the word is a palindrome and 
        False otherwise
        
        >>> is_palindrome('blaha')
        False
        
        >>> is_palindrome('redivider')
        True
    
    """
    
    return word == word[::-1]
    
import doctest
doctest.run_docstring_examples(is_palindrome,globals())

# %%
# string s1 is a palindrome if s1[0] == s1[-1] and s1[1:-1] is a palindrome

def is_palindrome(s1):
    """
        Takes in a string s1, returns True if s1 is a palindrome
        Returns False if it isn't
        
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('john')
    False
    """
    if len(s1) < 3:
        return s1[0] == s1[-1]
    else:
        return is_palindrome(s1[1:-1])

import doctest
doctest.run_docstring_examples(is_palindrome, globals())

# %%
def is_palindrome(a):
    if len(a)==0 or len(a)==1:
        return True
    else:
        if a[0]==a[len(a)-1]:
            #print a
            return is_palindrome(a[1:(len(a)-1)])
        else:
            return False

print is_palindrome('racecar')

print is_palindrome('palindromelap')
# Out:
# True
# False

# %%
def is_palindrome(word):
    '''
    >>> is_palindrome('Word')
    False
    >>> is_palindrome('Wordrow')
    True
    >>> is_palindrome('wo.rd ro?w')
    True
    >>> is_palindrome('Pana ma anap')
    False
    
    '''
    
    def process_word(word):
        word = word.lower()
        
        bad_chars = [' ', ',', '.', '?', '!', '-', '–', '"', "'"]
        
        for char in bad_chars:
            word = word.replace(char, '')
        return word

    def check_it(word):
        if len(word) in [1, 0]:
            return True
        elif word[0] != word[-1]:
            return False
        elif check_it(word[1:-1]):
            return True
        else:
            return False
        
    return check_it(process_word(word))

import doctest
doctest.testmod()
# doctest.run_docstring_examples(is_palindrome, globals(), verbose=True, name="Jus' Testin'")
# Out:
# TestResults(failed=0, attempted=4)

# %%
def is_palindrome(string):
    string = string.replace(' ', '')
    if first(string) == last(string):
        string = middle(string)
        if len(string) > 1:
            return is_palindrome(string)
        else:
            return True
    else:
        return False
        
def first(word):
    return word[0]

def middle(word):
    return word[1:-1]

def last(word):
    return word[-1]

print is_palindrome('a dog a panic in a pagoda')
print is_palindrome('adogapanicinapagoda')
# Out:
# True
# True

# %%
import doctest

def is_palindrome(word):
    """
    This function will take in a string and then determine whether it
    is a palindrome by checking the first and last letters, and then
    recursively checking the middle letters.
    
    Testing to make sure it hits all the way to the innermost letters, as well as
    simple cases for robustness.
    
    >>> is_palindrome("cavbac")
    False
    >>> is_palindrome("noon")
    True
    >>> is_palindrome("redivider")
    True
    >>> is_palindrome("livevil")
    True
    >>> is_palindrome("chicken")
    False
    """
    if len(word) < 2:
        return True
    elif word[0] != word[-1]:
        return False
    else:
        return is_palindrome(word[1:-1])
        
    
doctest.run_docstring_examples(is_palindrome, globals(),verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     is_palindrome("cavbac")
# Expecting:
#     False
# ok
# Trying:
#     is_palindrome("noon")
# Expecting:
#     True
# ok
# Trying:
#     is_palindrome("redivider")
# Expecting:
#     True
# ok
# Trying:
#     is_palindrome("livevil")
# Expecting:
#     True
# ok
# Trying:
#     is_palindrome("chicken")
# Expecting:
#     False
# ok

# %%
def is_anagram(a):
    a = a.replace(" ", "")
    b = a[::-1]
    if len(a) != len(b):
        return "Nope, not the same length"
    elif a in b:
        return True
    else:
        return False

is_anagram('taco cat')
# Out:
# True

# %%
def is_palindrome(s):
    if len(s)==1:
        return True
    if len(s)==2:
        if s[0]==s[1]:
            return True
        else:
            return False
    if s[0]==s[len(s)-1]:
        return is_palindrome(s[1:len(s)-1])
    else:
        return False
print is_palindrome("abdedba")
print is_palindrome("notactuallypalindrome")
# Out:
# True
# False

# %%
def is_palindrome(yoString):
    if len(yoString) <= 1:
        return True
    if yoString[0] == yoString[-1]:
        return is_palindrome(yoString[1:-1])
    return False

print is_palindrome('racecar')
print is_palindrome('palindrome')
print is_palindrome('aaaaaa')
# Out:
# True
# False
# True

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(n):
    """
    Checks to see if a word is a palindrome.
    """
    if len(n) ==1 or len(n) == 0: # to account for even and odd length words
        return True
    if first(n) != last(n):
        return False
    return is_palindrome(middle(n))

print is_palindrome('wonderful')
print is_palindrome('bob')
print is_palindrome('noon')
print is_palindrome('nooln')
# Out:
# False
# True
# True
# False

# %%
def is_palindrome(word):
    if len(word) <= 1:
        return True
    elif word[0] == word[-1]:
        return is_palindrome(word[1:-1])
    else:
        return False
    
print is_palindrome('arozaupalanalapuazora')
# Out:
# True

# %%
def is_palindrome(s):
    if(len(s)<=1):
        return True
    if s[0]==s[-1]:
        return is_palindrome(s[1:-1])
    return False

print is_palindrome('noon')
print is_palindrome('redivider')
print is_palindrome('banana')
# Out:
# True
# True
# False

# %%
def is_palindrome(word):
    """
    Tests if a word is a palindrome (spelled the same forward and back)
    
    >>> is_palindrome('boatstaob')
    True
    
    >>> is_palindrome('boattaob')
    True
    
    >>> is_palindrome('boatsaob')
    False
    """
    if len(word) <= 1:
        return True
    else:
        if word[0]==word[len(word)-1]:
            return is_palindrome(word[1:len(word)-1])
        else:
            return False

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=3)

# %%
def is_palindrome(s):
    if len(s)<2:
        return True
    else:
        if s[0]==s[-1]:
            if is_palindrome(s[1:-1]) is True:
                return True
        else:
            return False

is_palindrome('noon')
# Out:
# True

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(word):
    import string
    word = word.lower()
    word = word.translate(None, string.punctuation)
    word = word.translate(None, " ")
    if first(word)!=last(word):
        return False
    if len(word) <=1:
        return True
    return is_palindrome(middle(word))

print is_palindrome("Not a palindrome")
print is_palindrome("bob")
print is_palindrome("Bob")
print is_palindrome( "Egad, a base life defiles a bad age.")
print is_palindrome("A man, a plan, a canal -- Panama")
print is_palindrome("Doc, Note: I Dissent. A Fast Never Prevents A Fatness. I Diet On Cod.")
# Out:
# False
# True
# True
# True
# True
# True

# %% [markdown]
# ### Challenge (optional)
#
# Use the word list from [Chapter 9.1](http://www.greenteapress.com/thinkpython/html/thinkpython010.html) Exercise 1 to find all of the palindromes.

# %%
fin = open('words.txt')

def find_all_palindromes():
    palindromes_list = []
    for line in fin:
        word = line.strip()
        if palindrome(word):
            palindromes_list.append(word)
    return palindromes_list

print find_all_palindromes
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-a0cfc770912d> in <module>()
# ----> 1 fin = open('words.txt')
#       2
#       3 def find_all_palindromes():
#       4     palindromes_list = []
#       5     for line in fin:
#
# IOError: [Errno 2] No such file or directory: 'words.txt'

# %%
fil = open("words.txt") # how do I import text files?
for word in fil:
    if is_palindrome(word):
        print word
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-6eb35ce0d343> in <module>()
# ----> 1 fil = open("words.txt")
#       2 for word in fil:
#       3     if is_palindrome(word):
#       4         print word
#
# IOError: [Errno 2] No such file or directory: 'words.txt'

# %%
fin = open('words.txt')

def find_palindromes():
    palindromes = []
    for line in fin:
        word = line.strip()
        if is_palindrome(word):
            palindromes.append(word)
    return palindromes
        
print find_palindromes()
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
instream = open('words.txt')
palindromes = []
for line in instream:
    ln = line.strip()
    if palindrome(ln): palindromes.append(ln)
        
print palindromes
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
def first(word):
    return word[0]

def last(word):
    return word[-1]

def middle(word):
    return word[1:-1]

def is_palindrome(word):
    mid = middle(word)
    if first(word) == last(word):    
        if mid[:] == mid[::-1]:
            return True
    return False

fin = open('words.txt')
for line in fin:
    word = line.strip()
    if is_palindrome(word):
        print word
# Out:
# aa
# aba
# aga
# aha
# ala
# alula
# ama
# ana
# anna
# ava
# awa
# bib
# bob
# boob
# bub
# civic
# dad
# deed
# deified
# deked
# deled
# denned
# dewed
# did
# dud
# eke
# eme
# ere
# eve
# ewe
# eye
# gag
# gig
# hah
# halalah
# hallah
# huh
# kaiak
# kayak
# keek
# kook
# level
# madam
# marram
# mem
# mim
# minim
# mom
# mum
# noon
# nun
# oho
# otto
# pap
# peep
# pep
# pip
# poop
# pop
# pup
# radar
# redder
# refer
# reifier
# repaper
# reviver
# rotator
# rotor
# sagas
# sees
# selles
# sememes
# semes
# seres
# sexes
# shahs
# sis
# solos
# sos
# stets
# tat
# tenet
# terret
# tit
# toot
# tot
# tut
# vav
# waw
# wow
# yay

# %%
#Having trouble finding a downloadable copy of the text file...
#This is what I'd probably do, though.
"""
def is_palindrome(word):
    forward = word
    backward = word[::-1]
    if forward == backward:
        return True
    return False
    
def find_palindromes():
    palindrome_list = []
    #fin = (['blue', 'racecar', 'sushi', 'hoioh'])
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        if is_palindrome(word):
            palindrome_list.append(word)
    return palindrome_list      

print find_palindromes()
"""
# Out:
# ['racecar', 'hoioh']

# %%
fin = open('words.txt')
word_list = []
pali_list = []

for line in fin:
    word = line.strip()
    word_list.append(word)

for word in word_list:
    if is_palindrome(word):
        word_list.append(word)

# %%
def is_palindrome(string):
    '''Checks if a string is a palindrome, or a word that is spelled the same way backward and forward. 
        Input: string
        Return: True if palindrome, False if not.
    >>> is_palindrome('noon')
    True
    >>> is_palindrome('Noon')
    True
    >>> is_palindrome('A santa lived as a devil at NASA')
    True
    >>> is_palindrome('Do geese see god')
    True
    >>> is_palindrome('Will the real slim shady please stand up')
    False'''
    if type(' ') == type(string):
        pass
    else:
        string=str(string)
    string=string.lower()
    string=string.replace(" ","")
    length= len(string)
    if length % 2 == 0:
        if string[0]== string[length-1]:
            for n in range (1,length):
                if string[n] == string[length-n-1]:
                    continue
                else:
                    return False
            return True
        return False
    else:
        oddlength=length-1
        if string[0]==string[oddlength]:
            for n in range (0, oddlength):
                if string[n] == string[length-n-1]:
                    continue
                else:
                    return False
            return True
        return False

fin=open('words.txt')
for line in fin:
    word=line.strip()
    if is_palindrome(word) == True:
        print word
# Out:
# aa
# aba
# aga
# aha
# ala
# alula
# ama
# ana
# anna
# ava
# awa
# bib
# bob
# boob
# bub
# civic
# dad
# deed
# deified
# deked
# deled
# denned
# dewed
# did
# dud
# eke
# eme
# ere
# eve
# ewe
# eye
# gag
# gig
# hah
# halalah
# hallah
# huh
# kaiak
# kayak
# keek
# kook
# level
# madam
# marram
# mem
# mim
# minim
# mom
# mum
# noon
# nun
# oho
# otto
# pap
# peep
# pep
# pip
# poop
# pop
# pup
# radar
# redder
# refer
# reifier
# repaper
# reviver
# rotator
# rotor
# sagas
# sees
# selles
# sememes
# semes
# seres
# sexes
# shahs
# sis
# solos
# sos
# stets
# tat
# tenet
# terret
# tit
# toot
# tot
# tut
# vav
# waw
# wow
# yay

# %%
def find_all_palindromes():
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        if (is_palindrome(word)):
            print word
            
find_all_palindromes()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-ef0245c035f3> in <module>()
#       6             print word
#       7
# ----> 8 find_all_palindromes()
#
# <ipython-input-10-ef0245c035f3> in find_all_palindromes()
#       1 def find_all_palindromes():
# ----> 2     fin = open('words.txt')
#       3     for line in fin:
#       4         word = line.strip()
#       5         if (is_palindrome(word)):
#
# IOError: [Errno 2] No such file or directory: 'words.txt'

# %%
def word_list_palindromes():
    palindrome_list = []
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        if is_palindrome(word):
            palindrome_list.append(word)
    return palindrome_list

print word_list_palindromes()
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
def palindrome_count(words):
    count = 0
    for i in words:
        if is_palindrome(i) == True:
            count += 1
    return count

palindrome_count(['bob','cat','bananab', 'tree', 'eye'])

#I don't want to deal with a list that has 113,000 words, but I think 
#successfully testing it with a shorter list suggests it would work with
#a longer one
# Out:
# 2

# %%
#I can't figure out how to access the words list from the notebook

# %%
def find_all_palindromes():
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        if is_palindrome(word):
            print word
            #continue
        else:
            continue
find_all_palindromes()
# Out:
# aa
# aba
# aga
# aha
# ala
# alula
# ama
# ana
# anna
# ava
# awa
# bib
# bob
# boob
# bub
# civic
# dad
# deed
# deified
# deked
# deled
# denned
# dewed
# did
# dud
# eke
# eme
# ere
# eve
# ewe
# eye
# gag
# gig
# hah
# halalah
# hallah
# huh
# kaiak
# kayak
# keek
# kook
# level
# madam
# marram
# mem
# mim
# minim
# mom
# mum
# noon
# nun
# oho
# otto
# pap
# peep
# pep
# pip
# poop
# pop
# pup
# radar
# redder
# refer
# reifier
# repaper
# reviver
# rotator
# rotor
# sagas
# sees
# selles
# sememes
# semes
# seres
# sexes
# shahs
# sis
# solos
# sos
# stets
# tat
# tenet
# terret
# tit
# toot
# tot
# tut
# vav
# waw
# wow
# yay

# %%
def first(word):
    return word[0]
def last(word):
    return word[-1]
def middle(word):
    return word[1:-1]
def is_palindrome(word):
    if first(word) != last(word):
        return False
    elif len(word)<3:
        return True
    else:
        return is_palindrome(middle(word))
    print 'wat'
words_file = open('words.txt')
is_palindrome('mumum')
palindromes = []
for word in words_file:
    if is_palindrome(word.strip()):
        palindromes.append(word.strip())
print palindromes
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
fin = open('words.txt')
palindromes = []
for line in fin:
    word = line.strip()
    
    if is_palindrome(word):
        palindromes.append(word)
print palindromes
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
ls = []
text = open('words.txt')
for line in text:
    word = line.strip()
    if is_palindrome(word):
        ls.append(word)
        
print ls
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
def is_palindrome(word):
    if(len(word) <= 1):
        return True
    return((word[0] == word[len(word)-1]) and is_palindrome(word[1:len(word) - 1]))
parse = open('words.txt')
palindromes = []
for line in parse:
    word = line[:len(line)-1] #the lines have new line (\n) at the end
    if(is_palindrome(word)):
        palindromes.append(word)
print(palindromes)
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %% [markdown]
# List of palindromes from local script:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
fin = open('words.txt')
all_palindromes = []
for line in fin:
    word = line.strip()
    if is_palindrome(word):
        all_palindromes.append(word)
print all_palindromes
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
fin = open('words.txt') #haven't tested it out because I have no idea where to store words.txt
palindromeList = []
for line in fin:
    if is_palindrome(line.strip()):
        palindromeList.append(line.strip())

# %%
reader = open('words.txt')
pals = []
for word in reader:
    w = word.strip()
    #print word
    if is_palindrome(w):
        pals.append(w)
        
print pals
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
def build_list():
    fin = open('words.txt')
    result = [line.strip() for line in fin]
    return result

def find_palindromes(word_list):
    palindromes = [word for word in word_list if is_palindrome(word)]
    return palindromes

word_list = build_list()
print find_palindromes(word_list)
# Out:
# ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']

# %%
def find_dromes():
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        if is_palindrome(word):
            print word
# should work, but ipython won't open files?

# %% [markdown]
# ### Exercise 7
#
# A number `a` is a power of `b` if it is divisible by `b` and `a/b` is a power of `b`. Write a function called `is_power` that takes parameters `a` and `b` and returns `True` if `a` is a power of `b`. Note: you will have to think about the base case.

# %%
def is_power(a, b):
     if a < b: 
        return False
     if a == b: 
        return True
     else:
        return is_power(a / b, b)
is_power(9,3)
# Out:
# True

# %%
def is_power(a,b):
    if a == b:
        return True
    elif a > b:
        if a%b == 0:
            return is_power(a/b,b)
        else:
            return False
    else:
        return False
    
print is_power(27,3)
print is_power(25,5)
# Out:
# True
# True

# %%
def is_power (a, b):
    if a < b:
        return False
    elif a < 0 or b < 0:
        return False
    elif a == b:
        return True
    else:
        return is_power (a/b, b)
    
is_power(27, 3)
# Out:
# True

# %%
def is_power(a,b):
    if a>b:
        if a%b == 0:
            return True
        if a%b != 0:
            return False
    return is_power(a/b,b)


print is_power(81,3)

print is_power(5,2)

print is_power(8,2)
# Out:
# True
# False
# True

# %%
def is_power(a,b):
    if a is b:
        return True
    elif a%b == 0:
        return is_power(a/b,b)
    else:
        return False

is_power(27,3)
# Out:
# True

# %%
def is_power(a,b):
    """
    >>> is_power(4,2)
    True
    >>> is_power(3,2)
    False
    """
    if a == 1:
        return True
    return a%b == 0 and is_power(float(a)/b, b)


doctest.testmod()
# Out:
# TestResults(failed=0, attempted=6)

# %%
def is_power(a,b):
    """returns whether a is a power of b.
    doctests test for a is zeroeth power, a is first power, a is nth power, and a is not power.
    >>> is_power(1, 70)
    True
    >>> is_power(5, 5)
    True
    >>> is_power(128, 2)
    True
    >>> is_power(132, 2)
    False
    """
    if a == 1:
        return True
    elif a % b == 0:
        return is_power(a/b,b)
    else:
        return False

doctest.run_docstring_examples(is_power, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     is_power(1, 70)
# Expecting:
#     True
# ok
# Trying:
#     is_power(5, 5)
# Expecting:
#     True
# ok
# Trying:
#     is_power(128, 2)
# Expecting:
#     True
# ok
# Trying:
#     is_power(132, 2)
# Expecting:
#     False
# ok

# %%
def isPower(a, b):
    """
    If a is a power of b, returns True.  Else returns false.
    
    a: an integer
    b: another integer
    >>> isPower(4, 2)
    True
    >>> isPower(3, 3)
    True
    >>> isPower(0, 0)
    True
    >>> isPower(3, 2)
    False
    >>> isPower(1, 3)
    True
    """
    if type(a) == int and type(b) == int:
        if a == b:
            return True
        elif b == 0 and a != 0:
            return False
        if a == 1:
            return True
        elif a%b == 0 and (a/b)%b == 0:
            return True
        else:
            return False
    else:
        return ValueError

    
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=9)

# %%
def is_power(a,b):
    a = float(a)
    b = float(b)
    if a == b:
        return True
    if a < b:
        return False
    return a%b == 0 and is_power(a/b,b)

print is_power(4,2)
print is_power(5,2)
print is_power(81,3)
# Out:
# True
# False
# True

# %%
def is_power(a,b):
    """ Returns True/False for if a is a power of b.
    >>> is_power(3,2)
    True
    >>> is_power(1,5)
    True
    >>> is_power(6,6)
    True
    >>> is_power(2,0)
    False
    >>> is_power(6,1)
    False
    >>> is_power(6,3)
    False
    """
    if a == 0 or b == 0:
        return False
    elif b == 1:
        if a == 1:
            return True
        else:
            return False
    
    if a==1 or (a/b)==1:
        result = True
    elif a % b == 0 and a!=0:
        result = is_power((a/b),b)
    else:
        result = False
  
    return result


if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def is_power(a, b):
    """
    Returns if A is a power of b. 
    
    >>> power(10, 2)
    False
    
    >>> power(32, 2)
    True
    
    """
    if not (a % b == 0):
        return False
    if a/b == 1:
        return True
    else:
        return power(a/b, b)
    
import doctest
doctest.run_docstring_examples(palindrome, globals())

# %%
def is_power(a,b):
    if a == b:
        return True
    test1 = a%b
    a = a/b
    if test1 == 0 and is_power(a,b):
        return True
    else:
        return False

print is_power(126,2)
print is_power(128,2)
# Out:
# False
# True

# %%
def is_power(a, b):
    c = a % b
    d = (a/b) % b
    if c == 0 and d == 0:
        return True
    else:
        return False

# %%
def is_power(a, b):
    if a % b == 0:
        if (a/b) % b == 0:
            return True
    return False
#is_power(16,2)
#is_power(9,3)
is_power(16,3)
# Out:
# False

# %%
def is_power(a, b):#is a a power of b?
    if a == 0 or b == 0:   #prevents code from looping if use input is 0
        print 'error, invalid input'
        return false
    if a != b:
        if a%b == 0:
            return is_power((1.0*a)/b, b)
        else:
            return False
    else:
        return True
    
is_power(8, 2)
# Out:
# True

# %%
def is_power(a, b):
    if a == b:
        return True
    elif a%b == 0 and b != 1:
        return is_power(a/b, b)
    else:
        return False
print(is_power(4, 2))
print(is_power(27, 3))
print(is_power(81, 1))
# Out:
# True
# True
# False

# %%
def is_power(a,b):
    if a == 1:
        return True
    if a % b != 0:
        return False
    return is_power((a/b),b)

print is_power(4,2)
# Out:
# True

# %%
def is_power(a, b):
    if a%b != 0:
        return False
    else:
        return True
    c = a/b
    return is_power(c, b)

    
    
is_power(9, 3)
# Out:
# True

# %%
def is_power(a, b):
    
    if a == b: 
        return True 
    else:
        if a%b == 0: 
            return is_power(a/b, b)
        else: 
            return False 
    
        
is_power(512, 2)
# Out:
# True

# %%
def is_power(a,b):
    if a == 1:
        return True
    elif a%b == 0 and is_power(a/b, b) == True:
        return True
    else:
        return False

# %%
'''A number a is a power of b if it is divisible by b and a/b is a power of b. 
    Takes parameters a and b. 
    Returns True if a is a power of b.
    >>> is_power(8,2)
    True
    >>> is_power(1,1)
    True
    >>> is_power(0,0)
    True
    >>> is_power(2,5)
    False
    >>> is_power(6,0)
    False
    >>> is_power(768,4)
    False'''

def is_power(a,b):
    if b == 0:
        if a==0:
            return True
        else:
            return False
    elif a % b == 0:
        if (a/b) % b ==0:
            div= a/b
            while div > 1:
                div= div/b
            if div == 1:
                return True
            else:
                return False
        else:
            return False
    else:
        return False
    
    
    
if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def is_power(a, b):
    if (a/b) == 1:
        return True
    elif a%b > 0:
        return False
    elif (a%b == 0):
        is_power(a/b, b)

# %%
def is_power(a, b):
    a = float(a)           #both a and b must be floats or the rounding will not work
    b = float(b)
    if a > 1:
        if a/b < 1:        #if recieve a fractional answer, then it is not a power
            return False
    
        elif a/b == 1:     #a and b should eventually equal each other
            return True
    
        else:
            x = a/b        #updates value
            return is_power(x, b)
    else:
        return False
    
print'Is a a power of b?'        
is_power(input('Is: '), input('a power of: ') )
# Out:
# Is a a power of b?
# Is: 125
# a power of: 5
# True

# %%
def is_power(a, b):
    a = a * 1.0
    if (a / b == 1.0):
        return True
    elif (a / b < 1.0):
        return False
    else:
        return is_power(a / b, b)
    
print is_power(342, 7)
# Out:
# False

# %%
def is_power(a, b):
    
    if a/b > b:
        n = a/b
        return is_power(n, b)
        
    elif a/b < b:
        return False
    
    elif a/b == b:
        return True
        
#is_power(27, 3) #True
#is_power(5.0625, 1.5) #True
#is_power(5, 25) #False (wrong order)
is_power(116,2) #False (128 is True though!)
# Out:
# False

# %%
def is_power(a, b):
    if a/float(b) == 1:
        return True 
    elif a % b == 0:
        return is_power(a/b, b) 
    else:
        return False
        
    
is_power(81, 3)
# Out:
# True

# %%
def is_power(a,b):
    """ Uses recursion to check if a is a power of b. a and b must be integers
    >>> is_power(4,2)
    True
    >>> is_power(28,2)
    False
    >>> is_power(49,7)
    True
    >>> is_power(109,3)
    False
    """
    if a == b:
        return True
    elif a < b:
        return False
    elif a % b == 0 and is_power(a/b,b):
        return True
    else:
        return False
    
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=6)

# %%
def is_power(a,b):
    if a%b == 0:
        if a == b:
            return True
        a = a/b
        return is_power(a,b)
    else:
        return False
    
#is_power(17,2)
is_power(16,16)
# Out:
# True

# %%
def is_power(a, b):
    if a % b != 0: # % Divides left hand operand by right hand operand and returns remainder
        return False
    elif a/b == 1:
        return True
    else:
        return is_power((a/b),b)  #yay recursion
        
print is_power(16,2)
print is_power(25,5)
print is_power(2,16)
print is_power(4,10)
# Out:
# True
# True
# False
# False

# %%
def is_power(a, b):
    """
    Checks whether a is a power of b through recursion.
    
    >>> is_power(8, 2)
    True
    >>> is_power(9, 2)
    False
    >>> is_power(2, 4.0)
    We are only examining integer powers here.
    >>> is_power(2.0, 4)
    We are only examining integer powers here.
    >>> is_power(2.0, 4.0)
    We are only examining integer powers here.
    >>> is_power('a powerful string', 'mr noodle the cat')
    We are only examining integer powers here.
    """
    
    if not isinstance(a, int) or not isinstance(b, int):
        print 'We are only examining integer powers here.'
        return None
    elif a == b:
        return True
    elif a % b == 0:
        return is_power(a/b, b)
    else: 
        return False
    
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=11)

# %%
def is_power(a,b):
    if a==b:
        return True
    elif a%b==0:
        a=a/b
        recurse= is_power(a,b)
        return recurse
    else:
        return False

is_power(81,3)
# Out:
# True

# %%
'''checks if a is a power of b

>>> is_power(1, 7)
True
>>> is_power(2, 0)
False
>>> is_power(0,0)
True
>>> is_power(1, 0)
True
>>> is_power(32, 2)
True
>>> is_power(45, 3)
False

'''
def is_power(a, b):
    if a == 1:
        #any number to the zeroth power is 1
        return True
    #because we can't divide by 0, need a special case
    elif b == 0:
        if a == 0:
            #0 to the power of anything but 0 is 0
            return True
        else:
            #all powers of zero are zero or one (following convention 0^0=1)
            return False
    else:
        if a/b == float(a)/float(b):
            new_a = a/b
            return is_power(new_a, b)
        else:
            return False
print is_power(25, 5)
import doctest
doctest.testmod(verbose = True)
# Out:
# True
# Trying:
#     is_power(1, 7)
# Expecting:
#     True
# ok
# Trying:
#     is_power(2, 0)
# Expecting:
#     False
# ok
# Trying:
#     is_power(0,0)
# Expecting:
#     True
# ok
# Trying:
#     is_power(1, 0)
# Expecting:
#     True
# ok
# Trying:
#     is_power(32, 2)
# Expecting:
#     True
# ok
# Trying:
#     is_power(45, 3)
# Expecting:
#     False
# ok
# 8 items had no tests:
#     __main__.a
#     __main__.b
#     __main__.c
#     __main__.first
#     __main__.is_palindrome
#     __main__.is_power
#     __main__.last
#     __main__.middle
# 1 items passed all tests:
#    6 tests in __main__
# 6 tests in 9 items.
# 6 passed and 0 failed.
# Test passed.
# TestResults(failed=0, attempted=6)

# %%
def is_power(a,b):
    if a % b == 0:
        if (a/b) % b == 0:
            return True
    else:
        return False

# %%
def is_power(a,b):
    if a%b == 0:
        is_power(a/b,b)
        return True   
    else: 
        return False
    
is_power(20,2)
# Out:
# True

# %%
def is_power(a,b):
    """
    returns True if a is a power of b
    a is a power of b if it is divisible by b and a/b is a power of b
    
    >>> is_power(1,0)
    False
    >>> is_power(4,2)
    True
    >>> is_power(1,1)
    True
    >>> is_power(5,3)
    False
    >>> is_power(0,0)
    False
    >>> is_power(2,0)
    False
    >>> is_power(0,4)
    False
    """
    if a == 0 or b == 0:
        return False
    elif a == b:
        return True
    elif a % b == 0:
        return is_power(a/b,b)
        return True
    else:
        return False
        
import doctest
doctest.run_docstring_examples(is_power,globals())

# %%
def is_power(a,b):
    if a%b == 0:
        if a == b:
            return True
        if is_power(a/b,b)==True:
            return True
    else:
        return False
    
is_power(9,3)
# Out:
# True

# %%
def is_power(a, b):              
    """Checks if a is a power of b. 'Divisible' only makes sense for whole numbers, so we assume b and n are both 
    integers. Negative values of b work fine.
    """
    a, b = float(a), float(b)
    if b == a:
        return True
    elif abs(b) > abs(a) or a%b != 0:
        return False
    else:
        return is_power(a/b, b)
print is_power(-8, -2)
# Out:
# True

# %%
def is_power(a,b):
    if a%b == 0:
        if a/b == b:
            return True
        return is_power(a/b,b)
    else:
        return False
print is_power(16,2)
# Out:
# True

# %%
def is_power(a,b):
    """
    This checks if the number a is a power of b.
    
    >>> is_power(16,1.41421356237)
    True
    
    >>> is_power(81,3)
    True
    >>> is_power(12, 3)
    False
    >>> is_power(12, 1)
    False
    >>> is_power(1,1)
    True
    >>> is_power(9, -3)
    True
    """
    if a == b and a == 1:
        return True
    elif b == 1 or a == 1:
        return False
    a = 0.0 + a
    b = 0.0 + b
    i = 42  #this is an arbitrary number greater than 1
    while abs(i)>1:
        i = a/b
        a = i
        if approx_Equal(i):
            return True
    return False
def approx_Equal(x, tolerance=0.0000001):
    return abs(x-1) <= 0.5 * tolerance * (x + 1)

if __name__ == "__main__": 
    import doctest
    doctest.testmod()

# %%
def is_power(a, b):
    if a == b:
        return True
    if a % b:
        return False
    return is_power(a / b, b)

is_power(81, 3)
# Out:
# True

# %%
def is_power (a,b):
    '''
    input: two numbers
    output: True if a is a power of b
    false if not
    '''
    a = float(a)
    b = float(b)
    if a % b == 0 and (a % b) % b == 0:
        return True
    else:
        return False
    
is_power(16,2)
# Out:
# True

# %%
def is_power(a,b):
    if(a%b == 0):
        if(a!=b):
            return is_power(float(a)/b,b)
        else:
            return True
        
print(is_power(8,2))
# Out:
# True

# %%
def is_power(a,b):
    '''
    >>> is_power(3, 3)
    True
    >>> is_power(81, 3)
    True
    >>> is_power(4, 3)
    False
    >>> is_power(2, 3)
    False
    >>> is_power(6, 3)
    False
    '''
    if a == b:
        return True
    elif a%b == 0:
        return is_power(a/b,b)
    else:
        return False
    
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=5)

# %%
def is_power(a, b):
    if(a <= b):
        return a==b
    return((a/b)%1 == 0 and is_power(a/b, b))
print(is_power(27, 3))
print(is_power(12, 3))
# Out:
# True
# False

# %%
def is_power(a,b):
    """
    Checks if a is a power of b. Ints pls.
    """
    if a < b:
        return False
    if a == 1:
        return True
    if a%b == 0 and a != b:
        return is_power(a/b, b)
    else:
        return a == b
    
print is_power(128,2)
print is_power(128,3)
print is_power(2,2)
# Out:
# True
# False
# True

# %%
def is_power(a,b):
    if a<b:
        return False
    elif a==b:
        return True 
    elif a%b==0:
        return is_power(a/b,b) 
    else:
        return False
    
print is_power(12,6)
# Out:
# False

# %%
def is_power(a, b):
    if a ==1:
        return True
    elif a%b == 0 and is_power(a/b, b) == True:
        return True
    else:
        return False
    
is_power(25, 5)
# Out:
# True

# %%
def is_power(a,b):
    
    """Takes two ints. Returns True if a is a power of b, False otherwise
        
        
        >>> is_power(27,3)
        True
        
        >>> is_power(125,5)
        True
        
        >>> is_power(2,4)
        False
        
        >>> is_power(7,1)
        False
    """
    
    if a%b == 0 and b != 1:
        if is_power(a/b,b) or a == b:
            return True
    else:
        return False
        
import doctest
doctest.run_docstring_examples(is_power,globals())

# %%
def is_power(a,b):
    """
        Returns True if a is a power of b
        
    >>> is_power(27,3)
    True
    >>> is_power(32,4)
    False
    >>> is_power(27,2)
    False
    """
    if a <= b:
        return a == b
    elif not a%b:
        return is_power(a/b,b)
    else:
        return False

import doctest
doctest.run_docstring_examples(is_power, globals())

# %%
def is_power(a,b):
    if a==b:
        return True
    elif a%b==0:
        #print a,
        #print b
        return is_power(a/b,b)
    else:
        return False
    
print is_power(64,2)

print is_power(96,2)
# Out:
# True
# False

# %%
def is_power(a, b):
    '''
    >>> is_power(3, 3)
    True
    >>> is_power(9, 3)
    True
    >>> is_power(27, 3)
    True
    >>> is_power(15, 3)
    False
    '''
    if a == b:
        return True
    elif a % b == 0:
        return is_power(a/b, b)
    else:
        return False

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=8)

# %%
def is_power(a,b):
    if a==b:
        return True
    if a%b != 0:
        return False
    return is_power(a/b, b)

print is_power(27,3)
print is_power(16, 5)
print is_power(27.0, 3)
# Out:
# True
# False
# True

# %%
def is_power(a, b):
    """
    This function determines whether a is a power b through recursion.
    Testing for edge cases such as embedded false positives, long recursions,
    and when b is equal to 1
    
    >>> is_power(243, 3)
    True
    >>> is_power(125, 7)
    False
    >>> is_power(100, 5)
    False
    >>> is_power(2048, 2)
    True
    >>> is_power(2,1)
    False
    """
    if a/b == 1:
        return True
    elif a%b !=0 or b==1:
        return False
    else:
        return is_power(a/b,b)
    
doctest.run_docstring_examples(is_power, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     is_power(243, 3)
# Expecting:
#     True
# ok
# Trying:
#     is_power(125, 7)
# Expecting:
#     False
# ok
# Trying:
#     is_power(100, 5)
# Expecting:
#     False
# ok
# Trying:
#     is_power(2048, 2)
# Expecting:
#     True
# ok
# Trying:
#     is_power(2,1)
# Expecting:
#     False
# ok

# %%
def is_power(a, b):
    a1 = a/b  
    if a == b:
        return "A is B, idiot."
    elif a1 == b:
        return True
    elif a1 % b != 0 or a < b:
        return False
    else:
        return is_power(a1, b)
    
is_power(16, 2)
# Out:
# True

# %%
def is_power(a,b):
    if a == b:
        return True
    if a%b==0 and is_power(float(a)/float(b),b):
        return True
    return False
    
print is_power(62,2)
print is_power(27,3)
#is is_power(3,27) supposed to be true or false? I mean technically 3 is 27^-3 or something.
# Out:
# False
# False

# %%
def is_power(a,b):
    if a < b or a/float(b) != a/b:
        return False
    if a == b:
        return True
    return is_power(a/b,b)


print is_power(9,3)
print is_power(9,2)
print is_power(8,2)
# Out:
# True
# False
# True

# %%
def is_power(a, b):
    """
    Determines if the first input is a power of the second input. 
    """
    if a == b:
        return True
    if a < b:
        return 'This function does not account for the fact that square roots can be considered powers.  My apologies.'
    else:
        if a%b == 0:
            return is_power(float(a)/b, b)
        else:
            return False

print is_power(1, 4)
print is_power(9, 3)
print is_power(10, 3)
# Out:
# This function does not account for the fact that square roots can be considered powers.  My apologies.
# True
# False

# %%
def is_power(a,b):
    if a == b:
        return True
    elif a % b == 0:
        return is_power(a/b, b)
    else:
        return False
        
    
print is_power(7, 2)
# Out:
# False

# %%
def is_power(a,b):
    if a%b == 0:
        if a/b ==1:
            return True
        else:
            return is_power(a/b, b)
    elif a<=1:
        return is_power(a*b, b)
    return False

print is_power(4,2)
print is_power(1.0/2, 2)
print is_power(1.0/3, 2)
print is_power(1.0/8, 2)
print is_power(81,3)
# Out:
# True
# True
# False
# True
# True

# %%
def is_power(a,b):
    if a < b or a % b != 0:
        return False
    elif a == b:
        return True
    else:
        return is_power(a / b, b)

print is_power(1024,2)
print is_power(18,3)
# Out:
# True
# False

# %%
def is_power(a, b):
    if a%b==0 and is_power(a/b, b):
        return True
    elif a/b==1:
        return True
    else:
        return False
    
is_power(32, 2)
# Out:
# True

# %%
def is_power(a,b):
    if a%b != 0:
        return False
    elif a/b == 1:
        return True
    else:
        return is_power(a/b,b)

print(is_power(16,2))
print(is_power(36,3))
# Out:
# True
# False

# %% [markdown]
# ### Challenge (optional) - Exercise 8
#
# The greatest common divisor (GCD) of `a` and `b` is the largest number that divides both of them with no remainder.
#
# One way to find the GCD of two numbers is based on the observation that if `r` is the remainder when `a` is divided by `b`, then `gcd(a, b) = gcd(b, r)`. As a base case, we can use `gcd(a, 0) = a`.
#
# Write a function called `gcd` that takes parameters `a` and `b` and returns their greatest common divisor.

# %%
def gcd (a,b):
    
    if b == 0:
        return a
    else:
        r = a % b
        return gcd (b,r)
    
gcd (16,32)
# Out:
# -2

# %%
def gcd(a, b):
    """
    >>> gcd(4,2)
    2
    >>> gcd(16,24)
    8
    >>> gcd(23,17)
    1
    """
    if a == 0:
        return b
    if b == 0:
        return a
    return gcd(b, a%b)


doctest.testmod()
# Out:
# TestResults(failed=0, attempted=9)

# %%
def gcd(a, b):
    """
    >>> gcd(2, 0)
    2
    """
    if a == 0 and b == 0:
        return ValueError
    if a == 0 or b == 0:
        return a or b
    else:
        for i in range(1,100)
            if a%i == j and a%j == i
        
        r = a%b

# FUCK THIS
        
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=12)

# %%
def gcd(a,b):
    if b == 0:
        return a
    return gcd(b,a%b)

print gcd(15,12)
print gcd(16,12)
print gcd(3,5)
print gcd(12,15)
# Out:
# 3
# 4
# 1
# 3

# %%
def gcd(a, b):
    """
    Returns the greatest common divisor of a and b
    
    >>> gcd(12, 24)
    4
    
    >>> gcd(11, 16)
    1
    
    """
    if a == 0 or b == 0:
        return 0
    r = a % b
    return gcd(b, r)

import doctest
doctest.run_docstring_examples(palindrome, globals())

# %%
def gcd(a, b):
    if b == 0:
        return a
    else:
        return gcd(b, a%b)
    
gcd(70, 20)
# Out:
# 10

# %%
'''
    >>> gcd(12,16)
    4
    >>> gcd(33,22)
    11'''

def gcd(a,b):
    remaindera= a % b
    remainderb= b % a
    gcd=1
    small=min(a,b)
    for c in range (1,small):
        remaindera= a % c
        remainderb= b % c
        if remaindera == 0 and remainderb == 0:
            gcd=c
    return gcd
    
if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def gcd(a, b):
    if (a >= b and a % b == 0):
        return b
    elif (a < b):
        return gcd(b, a)
    else:
        return gcd(b, a%b)

print gcd(20, 35)
# Out:
# 5

# %%
def gcd(a, b):
    if b == 0:
        return a
    else:
        r = a-((a/b)*b)
        return gcd(b, r)
        
        
print gcd(5,4)
print gcd(91, 217)
print gcd(28, 70)
print gcd(0, 10)
# Out:
# 1
# 7
# 14
# 10

# %%
def gcd(a, b):
    """ Finds the greatest common divisor of a and b
    >>> gcd(9,6)
    3
    """
    r = a % b
    if r == 0:
        return b
    return gcd(b,r)

print gcd(27,24)
print gcd(699,38)
# Out:
# 3
# 1

# %%
def gcd(a, b): #returns greatest common divisor of a and b
    if b == 0:
        return a
    else:
        return gcd(b, a % b) #yay recursion
    
print gcd(25, 5)
print gcd(12, 8)
print gcd(2, 8)
print gcd(3, 5)
# Out:
# 5
# 4
# 2
# 1

# %%
def gcd(a, b):
    """
    Returns the greatest common divisor of a and b
    It will return something fairly useless 
    for floats that can't be ints, like 100.3
    
    >>> gcd(100, 75)
    25
    """
    r = a % b
    if r == 0:
        return b
    return gcd(b,r)

doctest.testmod()
# Out:
# TestResults(failed=0, attempted=11)

# %%
def gcd(a, b):
    if b == 0:
        return a
    else:
        r = a%b
        return gcd(b, r)
print gcd(35, 15)
# Out:
# 5

# %%
def gcd(a,b):
    """
    Returns gcd of a and b
    
    If r = remainder when a is divided by b, then gcd(a,b) = gcd(b,r)
    
    Base case: gcd(a,0) = a
    
    >>> gcd(5,3)
    1
    
    >>> gcd(4,2)
    2
    
    >>> gcd(45,60)
    15
    
    >>> gcd(60,45)
    15
    """
    
    if a % b == 0:
        return b
    elif b == 0:
        return a
    else:
        r = a % b
        return gcd(b,r) 
    
import doctest
doctest.run_docstring_examples(gcd,globals())

# %%
def gcd(a, b):
    if not isinstance(a, int) or not isinstance(b, int) or a<0 or b<0:
        return 'Input positive integers, dummy'
    if b == 0:
        return a
    else:
        return gcd(b, a%b)
print gcd(980235, 1238643)
# Out:
# 9

# %%
def gcd(a,b):
    if not isinstance(a,int) or not isinstance(b,int):
        print 'gcd is only defined for integers'
    elif b>a:
        return gcd(b,a)
    r = a%b
    if r == 0:
        return b
    return gcd(r,b)

gcd(8,7)
# Out:
# 1

# %%
def gcd(a,b):
    if a%b == 0:
        return b
    r = a%b
    return gcd(b,r)
gcd(32,24)
# Out:
# 8

# %%
# 6 is remainder of 15%9
# gcd is 3

# 9%6


def gcd(a,b):
    if(b == 0):
        return a
    else:
        return gcd(b,a%b)

print gcd(32,5)
# Out:
# 1

# %%
def gcd(a, b):
    if(b == 0):
        return a
    if(a%b == 0):
        return b
    return(gcd(b, a%b))
print(gcd(100, 70))
print(gcd(10, 10))
print(gcd(10, 3))
# Out:
# 10
# 10
# 1

# %%
def gcd(a,b):
    '''
    This function returns the greatest common divisor of a, b 
    where a is the larger number
    '''
    if b==0:
        return a
    else:
        return gcd(b,a%b)

print gcd(648,234)
# Out:
# 18
# 36 13

# %%
def gcd(a,b):
    """
    This function determines the greatest common divisor of two numbers.
    Checks for when the remainder works out, else it recurses.
    
    Testing for when they're very large, and for they're very small.
    
    >>> gcd(45,15)
    15
    >>> gcd(100,120)
    20
    >>> gcd(7,11)
    1
    >>> gcd(9999999999, 7777777777)
    1111111111
    >>> gcd(1,2)
    1
    """
    if b == 0:
        return a
    elif a%b == 0:
        return b
    else:
        return gcd(b,a%b)
    
doctest.run_docstring_examples(gcd,globals(),verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     gcd(45,15)
# Expecting:
#     15
# ok
# Trying:
#     gcd(100,120)
# Expecting:
#     20
# ok
# Trying:
#     gcd(7,11)
# Expecting:
#     1
# ok
# Trying:
#     gcd(9999999999, 7777777777)
# Expecting:
#     1111111111
# ok
# Trying:
#     gcd(1,2)
# Expecting:
#     1
# ok

# %%
def gcd(a,b):
    if b==0:
        return a
    return gcd(b,a%b)

print gcd(12,8)
print gcd(26,13)
# Out:
# 4
# 13

# %%
def gcd(a,b):
    if b == 0:
        return a
    return gcd(b, a%b)

print gcd(6,20)
# Out:
# 2

# %%
def gcd(a,b):
    if b == 0:
        return a
    return gcd(b,a%b)

print gcd(2,4)
print gcd(6,5)
print gcd(30,4)
print gcd(100,600)
# Out:
# 2
# 1
# 2
# 100

# %%
def gcd(a,b):
    if b == 0:
        return a
    else:
        r = a % b
        return gcd(b,r)
    
print gcd(216,32)
# Out:
# 8

# %% [markdown]
# ## Reading Journal feedback
#
# Have any comments on this Reading Journal? Feel free to leave them below and we'll read them when you submit your journal entry. This could include suggestions to improve the exercises, topics you'd like to see covered in class next time, or other feedback.
#
# If you have Python questions or run into problems while completing the reading, you should post them to Piazza instead so you can get a quick response before your journal is submitted.

# %% [markdown]
# It wasn't clear on the second required question that a recursive function was needed.

# %% [markdown]
# I've been ommiting challenge problems because I'm in a serious time crunch with work from other classes. Hopefully things will lighten up next week-- but even then I will likely try to do toolbox and mini-project stuff.

# %% [markdown]
# I don't think I 100% understand how to use recursion in Python, which is why I was unable to implement it into my work for this journal. Could you please explain it again in class? (Thank you in advance!)

# %% [markdown]
# This Journal was really effective at teaching me recursion because I had to do the Exercise 6 over and over til I got it, but I know I understand now because I was able to do the Exercise 7 on the FIRST TRY (a little proud of that one). I still don't understand the importance behind Exercise 4 though. That actually obfuscated things for me rather than clarifying them.
# Anyway, I just wanted to congratulate y'all because I thought recursion was going to be awful to learn, and this made it easy.

# %% [markdown]
# This was a fun chapter. I like recursion, wish we could do more with it.

# %% [markdown]
# So why did this book introduce recursion before loops? I do think it makes more sense in the order that we did it.
